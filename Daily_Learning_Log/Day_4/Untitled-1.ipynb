# %%
print('siri\'s world')
# Out:
# siri's world

# %%
print('Hello world')
# Out:
# Hello world

# %%
message='Hello world'

# %%
print(message)
# Out:
# Hello world

# %%
remainder="""

keep your phone in the cold and dry place 
to prevent overheating"""

# %%
print(remainder)
# Out:
# keep your phone in the cold and dry place
# to prevent overheating
